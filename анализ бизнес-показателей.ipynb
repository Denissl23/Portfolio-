# %% [markdown]
# <div class="alert alert-success"><div class='alert btn-success'>
# Денис, 😊буду рада, если смогла быть тебе полезной!)<br>
# Критичных ошибок нет. Молодец!)<br>
# С удовольствием принимаю проект!<br>
# И делюсь с тобой материалами.
# </div></div>
#
# [Продуктовые метрики: какие они бывают и как ими пользоваться](https://vc.ru/marketing/310152-produktovye-metriki-kakie-oni-byvayut-i-kak-imi-polzovatsya)   <br>
# [Метрики продукта, роста, эффективности и добавочной ценности](https://gopractice.ru/product/added_value_metrics/)   <br>
# [Видео - Что такое продуктовая аналитика](https://www.youtube.com/watch?v=oquId6GPadw)<br>
#
# <div class="alert alert-success"><div class='alert btn-success'>
# Надеюсь, ты найдешь для себя что-то интересное и полезное😊<br>
#
# **Желаю тебе удачи в дальнейшей учебе!** 😉 </div></div>

# %% [markdown]
# Денис, привет! Меня зовут Ирина Литвинова. Сегодня я проверю твой проект.<br>
# <br> Ты можешь обращаться ко мне на "ты"😏 Надеюсь, ты не будешь против, если и я буду обращаться к тебе на "ты". Но если для тебя это неприемлeмо, дай знать, пожалуйста) <br>
# <br> Мне очень важна твоя реакция на мои комментарии, особенно <font color='red'>красные</font>. Можешь реагировать, например, так ('исправлено', ...)<br>
# <br> Ты можешь реагировать на мои комментарии своими, выделяя их цветами и наиболее понравившимся тебе способом оформления, но явно  отличающимся от моих комментариев. <br>
# Это нужно, чтобы не создавалась путаница😉<br>
# Например, так:<br>
#
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> Были внесены следующие изменения ...<br></div>
#
#
# <br> Пожалуйста, не удаляй мои комментарии, так как они повышают качество повторного ревью и делают его быстрее)<br>
# <br> Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой руководитель будет поступать также, и я пытаюсь подготовить тебя именно к работе. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓<br>
#
# Для твоего удобства мои комментарии будут в <font color='green'>зеленой</font>, <font color='orange'>желтой</font> или <font color='red'>красной</font> рамках:<br>
# <br>
#
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <b>Ошибка:</b><br>
# Если требуются исправления. Работа не может быть принята с красными комментариями.<br></div>
#
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Если можно немного улучшить.<br></div>
#
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# Если все сделано отлично.<br></div>

# %% [markdown]
# ### Инструкция по выполнению проекта:
#
# Вы - маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несколько прошлых месяцев ваш бизнес постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Вам нужно разобраться в причинах этой ситуации.
#
# У вас в распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Вам предстоит изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# #### Шаг 1. Загрузите данные и подготовьте их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv. Скачать датасет
#  -   /datasets/orders_info_short.csv. Скачать датасет
#  -   /datasets/costs_info_short.csv. Скачать датасет
#
# #### Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# #### Шаг 3. Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?.
#
# #### Шаг 4. Маркетинг
# Выясните:
#
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# #### Шаг 5. Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
#
# Подумайте, нужно ли включать в анализ органических пользователей?
#
# #### Шаг 6. Напишите выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.
#
# #### Оформление:
# Задание выполните в Jupyter Notebook. Программный код заполните в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.
#
#
# #### Описание данных
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
#     User Id — уникальный идентификатор пользователя
#     Device — категория устройства пользователя
#     Session start — дата и время начала сессии
#     Session End — дата и время окончания сессии
#     Channel — идентификатор рекламного источника, из которого пришел пользователь
#     Region - страна пользователя
#
# Таблица orders_log_short (информация о заказах):
#
#     User Id — уникальный id пользователя, который сделал заказ
#     Event Dt — дата и время покупки
#     Revenue — выручка
#
# Таблица costs_short (информация о затратах на маркетинг):
#
#     Channel — идентификатор рекламного источника
#     Dt — дата
#     Costs — затраты на этот рекламный источник в этот день

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍 Есть введение в проект, план и описание данных. Отлично!<br>
# Стоит еще добавить название проекта.
#
# </div>

# %% [markdown]
# # Шаг 1. Загрузите данные и подготовьте их к анализу
# Загрузите данные о визитах, заказах и расходах в переменные. Оптимизируйте данные для анализа. Убедитесь, что тип данных в каждой колонке — правильный. Путь к файлам:
#
#  -   /datasets/visits_info_short.csv.
#  -   /datasets/orders_info_short.csv.
#  -   /datasets/costs_info_short.csv.

# %%
#импортируем библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import timedelta, datetime

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера </b>
#
# <b>Успех:</b><br>
# 👍 Здорово, что импортируешь необходимые библиотеки в первой ячейке. Так сразу понятно какие используются библиотеки и можно легко настроить свое окружение при необходимости.
# </div>

# %%
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# При загрузке датасета столбцы с датой имеют тип данных object. Можно перевести столбцы с датами к нужным типам на этапе загрузки датафрейми, указав параметр `parse_dates=['Session Start', 'Session End']` в `pd.read_csv`.<br>
# Подробнее по этой [ссылке](https://towardsdatascience.com/4-tricks-you-should-know-to-parse-date-columns-with-pandas-read-csv-27355bb2ad0e).
# </div>

# %% [markdown]
# ## Преобработка visits

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %%
#посмотрим информацию о датасете
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍Молодец, что проверяешь дубликаты.<br>
# </div>

# %%
#переименуем столбцы
visits.columns = ['user_id', 'region', 'device', 'channel', 'session_start', 'session_end']

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Можно еще так привести все названия столбцов в нижний регистр, а пробелы заменить на `_`: `df.columns = [x.lower().replace(' ', '_') for x in df.columns.values]`
# </div>

# %%
visits['session_end'] = pd.to_datetime(visits['session_end'], format = '%Y-%m-%d %H:%M:%S')
visits['session_start'] = pd.to_datetime(visits['session_start'], format = '%Y-%m-%d %H:%M:%S')

# %% [markdown]
# Все в порядке. Дубликатов и пропусков нет, мы привели названия столбцов к удобному регистру

# %% [markdown]
# ## Преобработка orders

# %%
#проделаем тоже самое с orders
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
orders.columns = ['user_id', 'event_dt', 'revenue']

# %%
#приведем столбец к дате
orders['event_dt'] = pd.to_datetime(orders['event_dt'], format = '%Y-%m-%d %H:%M:%S')

# %% [markdown]
# С таблицей `orders` также все хорошо. Мы изменили тип и названия столбцов датафрейма

# %% [markdown]
# ## Предобработка costs

# %%
#и также проверим costs
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.duplicated().sum()
# Out:
# 0

# %%
costs.columns = ['dt', 'channel', 'costs']

# %%
costs['dt'] = pd.to_datetime(costs['dt'], format = '%Y-%m-%d')

# %% [markdown]
# С преобработкой на этом всё! Мы внесли нужные нам изменения для последуюшей обработки данных

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
# 👍С данными познакомились,  дубликаты проверены, необходимые преобразования сделаны! Отлично!<br>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# На этапе знакомства с данными еще можно посмотреть уникальные значения категориальных данных, так мы сразу проверяем данные на соответствие условиям.<br>
#
# </div>

# %% [markdown]
# # Шаг 2. Задайте функции для расчета и анализа LTV, ROI, удержания и конверсии
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.

# %% [markdown]
# **Функция для расчета LTV**

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# **Функции для построения графиков**

# %%
def filter_data(df, window):
    # для каждой колонки применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(25, 15))
    plt.suptitle('Динамика LTV и ROI', fontsize=20, fontweight='bold')

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))
    plt.suptitle('Динамика конверсии', fontsize=25, fontweight='bold')

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
def plot_retention(retention, retention_history, horizon):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))
    plt.suptitle('Динамика Retention Rate', fontsize=25, fontweight='bold')

    # исключаем размеры когорт и удержания первого дня
    retention = retention.drop(columns=['cohort_size', 0])

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey = ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    #ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    #columns = [
     #   name
      #  for name in retention_history.index.names
       # if name not in ['dt', 'payer']
    #]
    # фильтруем данные, строим сводную таблицу и график по ней
    #retention_history.query('payer == True').pivot_table(
     #   index='dt', columns=columns, values=horizon-1, aggfunc='mean'
    #).plot(grid=True, ax=ax3)
    #plt.xlabel('Дата привлечения')
    #plt.title(
    #    'Динамика удержания платящих пользователей на {}-й день'.format(
     #       horizon
      #  )
    #)
    
    # в четвёртой ячейке — динамика удержания неплатящих
    #ax4 = plt.subplot(2, 2, 4, sharey = ax3)
    # фильтруем данные, строим сводную таблицу и график по ней
    #retention_history.query('payer == False').pivot_table(
     #   index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    #).plot(grid=True, ax=ax4)
    #plt.xlabel('Дата привлечения')
    #plt.title(
     #   'Динамика удержания неплатящих пользователей на {}-й день'.format(
      #      horizon
       # )
    #)

    # исключаем наложение графиков друг на друга
    plt.tight_layout()

    plt.show()

# %% [markdown]
# **функция для  Retention Rate**

# %%
def get_retention(profiles, sessions, observation_date, horizon_days, dimensions = [], ignore_horizon = False):
    
    # решаем какие столбцы оставим для группировки удержания, столбец признака платящего пользователя остается всегда
    dimensions = ['payer'] + dimensions
    
    # оттсекаем всех пользователей, которые не могли "дожить" до нужного горизонта 
    # (присоединились позже чем observation_date - horizon)
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(days = horizon_days - 1)
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # формируем массив сырых данных
    result_raw = result_raw.merge(sessions[['user_id', 'session_start']], on = 'user_id', how = 'left')
    result_raw['lifetime'] = (result_raw['session_start'] - result_raw['first_ts']).dt.days
    
    # функция группировки по нужному набору измерений
    def group_by_dimensions(df, dims, horizon_days):     
        result = df.pivot_table(index = dims, columns = 'lifetime', values = 'user_id', aggfunc = 'nunique')     # строим "треугольную таблицу" 
        cohort_sizes = df.groupby(dims).agg({'user_id': 'nunique'}).rename(columns = {'user_id': 'cohort_size'}) # определяем размеры когорт
        result = cohort_sizes.merge(result, on = dims, how = 'left').fillna(0)                                   # присоединяем размеры когорт к треугольной таблице
        result = result.div(result['cohort_size'], axis = 0)                                                     # делим каждый из столбцов на размер когорты - расчитываем % удержания (retention rate)
        result = result[['cohort_size'] + list(range(horizon_days))]                                             # оставляем только наблюдения до нужного горизонта и столбец размеров когорт
        result['cohort_size'] = cohort_sizes                                                                     # пересприсваиваем столбец размеров когорт, ведь во время деления он превратился в 1
        return result
    
    # расчитываем удержание 
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)
    
    # рассчитываем удержание по всем параметрам + дата
    result_in_time = group_by_dimensions(result_raw, dimensions + ['dt'], horizon_days)
    
    # возвращаем и таблицы удержания и сырые данные (чтобы в случае чего можно было в них покопаться при отладке)
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# **функция для Conversion Rate**

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу конверсии
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        # считаем сумму с накоплением для каждой строки
        result = result.fillna(0).cumsum(axis = 1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # добавляем размеры когорт в таблицу конверсии
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# **функция для определния профилей пользователей**

# %%
# добавляем параметр ad_costs — траты на рекламу
def get_profiles(sessions, orders, ad_costs, event_names=[]):

    # сортируем сессии по ID пользователя и дате привлечения
    # группируем по ID и находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
         # время первого посещения назовём first_ts
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()  # возвращаем user_id из индекса
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['first_ts'] = pd.to_datetime(profiles['first_ts'], format='%Y-%m-%d %H:%M:%S')
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())



    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
         # столбец с числом пользователей назовём unique_users
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()  # возвращаем dt и channel из индексов
    )
    profiles['dt'] = pd.to_datetime(profiles['dt'], format='%Y-%m-%d')
    new_users['dt'] = pd.to_datetime(new_users['dt'], format='%Y-%m-%d')
    # объединяем траты на рекламу и число привлечённых пользователей
    # по дате и каналу привлечения
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    # результаты сохраним в столбец acquisition_cost (CAC)
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    
    ad_costs['dt'] = pd.to_datetime(ad_costs['dt'], format='%Y-%m-%d')
    # добавим стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # органические пользователи не связаны с данными о рекламе,
    # поэтому в столбце acquisition_cost у них значения NaN
    # заменим их на ноль, ведь стоимость привлечения равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
    
    return profiles  # возвращаем профили с CAC

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Все функции в одном месте. Отлично!
#
# </div>

# %%
#посмторим таблицу с профилями
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region         dt  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States 2019-05-07
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States 2019-07-09
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France 2019-10-01
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany 2019-08-22
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States 2019-10-02
#
#        month  payer  acquisition_cost
# 0 2019-05-01   True          1.088172
# 1 2019-07-01  False          1.107237
# 2 2019-10-01  False          0.000000
# 3 2019-08-01  False          0.988235
# 4 2019-10-01  False          0.230769

# %% [markdown]
# **Итог:**
#
# Функции для расчета метрик заданы, пользовательские профили построены. Можно переходить к анализу данных

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Данные готовы к исследованию.
#
# </div>

# %% [markdown]
# # Шаг 3. Проведите исследовательский анализ данных
#
# Постройте профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выясните:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ###  Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?

# %%
#сводная таблица по странам
users_by_region = profiles.groupby('region', as_index=False).agg(
            {'user_id': 'nunique', 'payer': 'sum'})
users_by_region.columns = ['region', 'total_users', 'total_payers']

#посмторим на процент платящих пользователей
users_by_region['percentage_of_payers'] = round(users_by_region['total_payers'] / users_by_region['total_users'] * 100, 1)

users_by_region.sort_values(by='total_users', ascending=False).reset_index(drop=True)
# Out:
#           region  total_users  total_payers  percentage_of_payers
# 0  United States       100002          6902                   6.9
# 1             UK        17575           700                   4.0
# 2         France        17450           663                   3.8
# 3        Germany        14981           616                   4.1

# %%
#построим графики для видимости количества пользователей
plt.figure(figsize=(15, 5))
plt.suptitle('Графики количества пользователей по странам', fontsize=25, fontweight='bold')

plt.subplot(1, 2, 1)
plt.bar(users_by_region['region'], users_by_region['total_users'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва пользователей по странам')
plt.xlabel('Страна')
plt.ylabel('Пользователи')

plt.subplot(1, 2, 2)
plt.bar(users_by_region['region'], users_by_region['total_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва платящих пользователей по странам')
plt.xlabel('Страна')
plt.ylabel('Пользователи')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.bar(users_by_region['region'], users_by_region['percentage_of_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График процентного соотношения платящих пользователей по странам', fontsize=20, fontweight='bold')
plt.xlabel('Страна')
plt.ylabel('Проценты, %')
# Out:
# Text(0, 0.5, 'Проценты, %')

# %% [markdown]
# **Вывод:**
#
# По графику мы видим, что самое большое количество пользователей приходит из `США`, а количество пользователей из `Франции, Германии и Великобритании` примерно одинаково, но меньше всего пользователей приходят из `Германии`. Такая же тенденция сохраняется и для количества платящих пользователей: достаточно большая разница между США и остальными странами. Можно ещё заметить, что процентное соотношение платящих пользователей самое большое также у Штатах

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Нам еще полезно будет посмотреть на % платящих пользователей,<br>
# Понятно, что в США кол-во плат.пользователей больше, т.к. там и самих пользователей больше.<br>
# А вдруг % в другой стране больше? Это надо проверить)<br>
# Т.е. надо найти % платящих пользователей для каждого региона от всех пользователей этого региона. Другими словами - конверсию в покупателя.<br>
#     Например, в сводной таблице `users_by_region`  среднее по столбцу `payer` и будет долей.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> добавил % платящих пользователей и добавил график<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Отлично! По конвертации и по кол-ву пользователей в приоритете Америка.
#
# </div>

# %% [markdown]
# ### Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?

# %%
#таблица по устройствам
users_by_device = profiles.groupby('device', as_index=False).agg(
            {'user_id': 'nunique', 
             'payer': 'sum'})
users_by_device.columns = ['device', 'total_users', 'total_payers']

#посмторим на процент платящих пользователей
users_by_device['percentage_of_payers'] = round(users_by_device['total_payers'] / users_by_device['total_users'] * 100, 1)

users_by_device.sort_values(by='total_users', ascending=False).reset_index(drop=True)
# Out:
#     device  total_users  total_payers  percentage_of_payers
# 0   iPhone        54479          3382                   6.2
# 1  Android        35032          2050                   5.9
# 2       PC        30455          1537                   5.0
# 3      Mac        30042          1912                   6.4

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍 Не удивительно, что пользователи Apple конвертируются лучше)
#
# </div>

# %%
plt.figure(figsize=(15, 5))
plt.bar(users_by_device['device'], users_by_device['percentage_of_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График процентного соотношения платящих пользователей по устройствам', fontsize=20, fontweight='bold')
plt.xlabel('Страна')
plt.ylabel('Проценты, %')
# Out:
# Text(0, 0.5, 'Проценты, %')

# %%
plt.figure(figsize=(15, 5))
plt.suptitle('Графики количества пользователей по девайсам', fontsize=25, fontweight='bold')

plt.subplot(1, 2, 1)
plt.bar(users_by_device['device'], users_by_device['total_users'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва пользователей по девайсам')
plt.xlabel('Устройство')
plt.ylabel('Пользователи')

plt.subplot(1, 2, 2)
plt.bar(users_by_device['device'], users_by_device['total_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва платящих пользователей по девайсам')
plt.xlabel('Устройство')
plt.ylabel('Пользователи')

plt.tight_layout()
plt.show()

# %%
#также будет полезно посмотреть на разбивку по странам

#функция для построения графика в виде "пирога"
def graph_2(data, region, axes):
    data = profiles.loc[(profiles['region']==region) & (profiles['payer']==True)].groupby('device').agg({'user_id': 'nunique'})
    data.plot(y='user_id', kind='pie', autopct='%1.0f%%', 
              legend=False,
              ax=axes,  wedgeprops={'lw':3,'edgecolor':"white"},
              title=f'Соотношение в {region}').set(ylabel='')
    plt.tight_layout()

#задаем параметры графиков
fig, axes = plt.subplots(1, 4, figsize=(12, 6))

fig.suptitle('Соотношение платящих пользователей по девайсам в странах', fontsize=25, fontweight='bold')
graph_2(profiles, 'UK', axes[0])
graph_2(profiles, 'Germany', axes[1])
graph_2(profiles, 'France', axes[2])
graph_2(profiles, 'United States', axes[3])
plt.show()

# %% [markdown]
# **Вывод:**
#
# 1. Если брать общее количество пользователей из всех стран, то самое популярное устройство - `Iphone`. Затем чуть меньше пользуются `Android, Mac и PC`. Но процент платящих пользователей самый большоу у `MAC`
# 2. Если же учитывать разделение по странам, то ситуация немного меняется: только в США большинство пользователей пользуются `Iphone`. Во всех осталльных странах самый популряный девайс - `PC`

# %% [markdown]
# ### По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
#пользователи по каналм
users_by_channel = profiles.groupby('channel', as_index=False).agg(
            {'user_id': 'nunique', 
             'payer': 'sum'})
users_by_channel.columns = ['channel', 'total_users', 'total_payers']

#посмторим на процент платящих пользователей
users_by_channel['percentage_of_payers'] = round(users_by_channel['total_payers'] / users_by_channel['total_users'] * 100, 1)

users_by_channel.sort_values(by='total_users', ascending=False).reset_index(drop=True)
# Out:
#                channel  total_users  total_payers  percentage_of_payers
# 0              organic        56439          1160                   2.1
# 1             FaceBoom        29144          3557                  12.2
# 2               TipTop        19561          1878                   9.6
# 3   OppleCreativeMedia         8605           233                   2.7
# 4              LeapBob         8553           262                   3.1
# 5       WahooNetBanner         8553           453                   5.3
# 6       RocketSuperAds         4448           352                   7.9
# 7         MediaTornado         4364           156                   3.6
# 8              YRabbit         4312           165                   3.8
# 9           AdNonSense         3880           440                  11.3
# 10      lambdaMediaAds         2149           225                  10.5

# %%
plt.figure(figsize=(15, 5))
plt.bar(users_by_channel['channel'], users_by_channel['percentage_of_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График процентного соотношения платящих пользователей по каналам', fontsize=20, fontweight='bold')
plt.xticks(rotation=45)
plt.xlabel('Страна')
plt.ylabel('Проценты, %')
# Out:
# Text(0, 0.5, 'Проценты, %')

# %%
plt.figure(figsize=(20, 10))
plt.suptitle('Графики количества пользователей по каналам привлечения', fontsize=25, fontweight='bold')

plt.subplot(1, 2, 1)
plt.bar(users_by_channel['channel'], users_by_channel['total_users'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва пользователей по каналам')
plt.xticks(rotation=45)
plt.xlabel('Устройство')
plt.ylabel('Пользователи')

plt.subplot(1, 2, 2)
plt.bar(users_by_channel['channel'], users_by_channel['total_payers'], color=['blue', 'green', 'orange', 'red'])
plt.title(label='График кол-ва платящих пользователей по каналам')
plt.xticks(rotation=45)
plt.xlabel('Устройство')
plt.ylabel('Пользователи')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод:**
#
# 1. Больше всего пользоватлей приходит с канала `organic` - `56 439`. Затем идет канал `FaceBoom` - `19 561` пользователей.
# 2. Что же касается платящих пользователей, то здесь с большим преимуществом лидирует канал `FaceBoom` - `3 557`. На втором месте канал - `TipTop` приносит `1 878` платящих пользователей.

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Денис, осталось найти % платящих пользователей для каждого устройства и канала по аналогии с регионами, т.е. конверсию в покупателя.</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> все исправил здесь<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Исследовательский анализ выполнен отлично!
#
# </div>

# %% [markdown]
# # Шаг 4. Маркетинг
#
# Выясните:
# - Сколько денег потратили? Всего / на каждый источник / по времени
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# **4.1 Сколько денег потратили? Всего / на каждый источник / по времени**

# %%
#посчитаем общую сумму за все время и по источникам
costs['dt'] = pd.to_datetime(costs['dt'], format = '%Y-%m-%d')
costs['month'] = costs['dt'].dt.month
total_cost = int(costs['costs'].sum())

cost_per_channel = costs.groupby('channel', as_index=False).agg({'costs':'sum'}).rename(columns={'costs': 'total_costs'})

print(f'Всего потратили на рекламу: {total_cost}')
cost_per_channel.sort_values(by='total_costs', ascending=False).reset_index(drop=True)
# Out:
# Всего потратили на рекламу: 105497
#               channel  total_costs
# 0              TipTop     54751.30
# 1            FaceBoom     32445.60
# 2      WahooNetBanner      5151.00
# 3          AdNonSense      3911.25
# 4  OppleCreativeMedia      2151.25
# 5      RocketSuperAds      1833.00
# 6             LeapBob      1797.60
# 7      lambdaMediaAds      1557.60
# 8        MediaTornado       954.48
# 9             YRabbit       944.22

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Здесь стоит обратить внимание, что из FaceBoom платящих пользователей приходит в 2 раза больше, чем из TipTop. Это при том, что расходов на FaceBoom в 1,7 раз меньше.  <br>
#
#
# </div>

# %%
#теперь посчитаем затраты по месяцам
costs['month'] = costs['dt'].dt.month
cost_per_month = costs.pivot_table(index = 'month', columns = 'channel', values = 'costs', 
                      aggfunc = 'sum')

cost_per_month.plot(grid=True, figsize=(16, 7), title='Динамика затрат по каналам привлечения', xlabel='месяц', ylabel='сумма')
# Out:
# <AxesSubplot:title={'center':'Динамика затрат по каналам привлечения'}, xlabel='месяц', ylabel='сумма'>

# %%
#теперь посчитаем затраты по месяцам
costs['week'] = costs['dt'].dt.isocalendar().week
cost_per_week = costs.pivot_table(index = 'week', columns = 'channel', values = 'costs', 
                      aggfunc = 'sum')

cost_per_week.plot(grid=True, figsize=(16, 7), title='Динамика затрат по каналам привлечения', xlabel='неделя', ylabel='сумма')
# Out:
# <AxesSubplot:title={'center':'Динамика затрат по каналам привлечения'}, xlabel='неделя', ylabel='сумма'>

# %% [markdown]
# **Вывод:**
#
# 1. Всего на рекламу за все время потратили - `105 497`
# 2. Больше всего средств потратили на каналы `TipTop` и `FaceBoom` - `54 751` и `32 445` соответственно
# 3. По динамке на графике видно, что у всех каналов, кроме `TipTop` и `FaceBoom` динамика изменения потраченных средств примерно одинакова. Но в эти два канала привлечения вкладывали больше всего денег. Самый пик трат на канал `TipTop` приходится на 9 месяц - более 12 тысяч

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Верно. Есть два дорогих канала - TipTop и FaceBoom. Здесь еще было бы полезно посмотреть сколько каждый регион тратит на канал. Так мы увидим кто пользуется дорогими каналами и в каких объемах.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Здесь нам еще надо построить такой же график расходов по каналам во времени **по неделям**. Денис, построй, пожалуйста)</s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> график по неделям добавлен<br></div>

# %% [markdown]
# **4.2 Сколько в среднем стоило привлечение одного покупателя из каждого источника?**

# %%
#CAC по каналам
cost_per_person = profiles.groupby('channel').agg({'acquisition_cost': 'mean'})
cost_per_person.sort_values('acquisition_cost', ascending=False)
# Out:
#                     acquisition_cost
# channel
# TipTop                      2.799003
# FaceBoom                    1.113286
# AdNonSense                  1.008054
# lambdaMediaAds              0.724802
# WahooNetBanner              0.602245
# RocketSuperAds              0.412095
# OppleCreativeMedia          0.250000
# YRabbit                     0.218975
# MediaTornado                0.218717
# LeapBob                     0.210172
# organic                     0.000000

# %%
#построим график CAC
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(16, 7), title='Динамика стоимости привлечения клиента по каналам', xlabel='месяц', ylabel='стоимость')
# Out:
# <AxesSubplot:title={'center':'Динамика стоимости привлечения клиента по каналам'}, xlabel='месяц', ylabel='стоимость'>

# %% [markdown]
# **Вывод:**
#
# 1. Самое дорогое привлечение пользователей - канал `TipTop`: средняя стоимость - `2.79`. На втором месте по стоимости `FaceBoom` - `1.11` в среднем
# 2. По графику мы видим, что линяя, принадлежащая каналу `TipTop`, имеет ступенчатый вид с повышением цены. У каналов `AdNonSense` и `lambdaMediaAds` наблюдаются небольшие колебания в цене

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 И  еще важно заметить - высокий САС не гарантирует высокую конвертацию в платящих пользователей.
#
# </div>

# %% [markdown]
# # Шаг 5. Оцените окупаемость рекламы для привлечения пользователей
#
# С помощью LTV и ROI:
# - Проанализируйте общую окупаемость рекламы;
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам;
# - Проанализируйте окупаемость рекламы с разбивкой по странам;
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам.
#
# Опишите проблемы, которые вы обнаружили. Ответьте на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Опишите возможные причины обнаруженных проблем и сформируйте рекомендации для рекламного отдела. При решении этого шага считайте, что вы смотрите данные 1-го ноября 2019 года и что в вашей организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.

# %% [markdown]
# **5.1 Проанализируйте общую окупаемость рекламы**

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Перед анализом нам лучше исключить органических пользователей из profiles, т.к. мы за них не платим.<br>
#     Чтобы графики показывали информацию только по "платным" пользователям.<br>   </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> готово<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍Теперь графики отображают достоверную информацию.
#
# </div>

# %%
#уберём органический канал из профилей
profiles = profiles.query('channel != "organic"')

# %%
#момент анализа
observation_date = datetime(2019, 10, 27).date()

#горизонт анализа
horizon_days = 14

# %%
#используем функция для LTV и ROI
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, horizon_days)

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days)
plot_conversion(conversion, conversion_history, horizon_days)

# %%
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, horizon_days)
plot_retention(retention, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
#
# - исходя из графика ROI, мы видим, что реклама не окупается. Линия ROI не пересекает линию окупаемости и равна примерно `80%`
# - конверсия первого дня - примеро `55%`, конверсия стремится вверх и достигает отметки в `80%`
# - как и ожидалось, удержание платящих пользователей лучше, чем у неплатящих. Retention rate 14 дня для платящих пользователей - около `11%`

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Без органики ROI будет еще меньше.<br>
#
#
# </div>

# %% [markdown]
# **5.2 Проанализируйте окупаемость рекламы с разбивкой по устройствам**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, horizon_days, ['device'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days, ['device'])
plot_conversion(conversion, conversion_history, horizon_days)

# %%
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, horizon_days, ['device'])
plot_retention(retention, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
#
# - самые высокие показатели LTV - у пользователей `MAC и IPHONE`. А самый низкий LTV у PC. Что же касается окупаемости рекламы, то у нас окупились только Android и PC
# - самая лучшая динамика конверсии у `MAC`. А самый худшая динамика - `PC`. Также на графике динамики конверсии, мы видим несколько явных провалов у устройства PC
# - самое лучшее удержание пользователей у PC. У остальных девайсов Retention Rate примерно одинаковый
# - окупается всего лишь один девайс - `PC`

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера</b>
#
# <b>Совет:</b><br>
# Без органики ROI также станет меньше.<br>
#
#
# </div>

# %% [markdown]
# **5.3 Проанализируйте окупаемость рекламы с разбивкой по странам**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, horizon_days, ['region'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days, ['region'])
plot_conversion(conversion, conversion_history, horizon_days)

# %%
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, horizon_days, ['region'])
plot_retention(retention, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
#
# - на графиках мы видим, что самый лучший `LTV` у `США`, но также видно, что стоимость привлечения пользователей в США намного больше остальных стран. У Великобритании ROI немного превышает `150%`
# - видно, что у `Германии, Великобритании и Франция` очень хорошая окупаемость - реклама окупилась уже на 6 день. Но в то же время у США  ROI не преодолел порог окупаемости
# - самая лучшая конверсия у США - почти `10%`. Также заметно, что пик конверсии у США был между июнем и июлем
# - сразу выделяется самое худшее удержаниие платящих пользователей у `США`, у остальных стран наблюдаются небольшие колебания в динамике   Retention

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера</b>
#
# <b>Успех:</b><br>
#     👍 Ты правильно обращаешь внимание на Америку, там ситуация по ROI самая печальная.<br>
# А еще стоит учитывать, что платящих пользователей там больше, конверсия лучше. <br>
# Значит, нам надо предложить решение, рекомендации для США.
# </div>

# %% [markdown]
# **5.4 Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам**

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles, orders, observation_date, horizon_days, ['channel'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %%
conversion_raw, conversion, conversion_history = get_conversion(profiles, orders, observation_date, horizon_days, ['channel'])
plot_conversion(conversion, conversion_history, horizon_days)

# %%
retention_raw, retention, retention_history = get_retention(profiles, visits, observation_date, horizon_days, ['channel'])
plot_retention(retention, retention_history, horizon_days)

# %% [markdown]
# **Вывод:**
#
# - на графике LTV явно выделяются рекламные источники `lambdaMediaAds` и `TipTop`. Самый пик LTV у `lamdbaMediaAds` приходится на начало июня
# - реклама не окупилась всего в трёх источниках: `TipTop`, `FaceBoom` и `AdNonSense`. Самый высокий ROI был у канала `YRabbit` между июлем и августом
# - самая лучшая конверсия у канала `FaceBoom` - `12%`, но в то же время в этом канале реклама не окупается
# - худшее удержание у `FaceBoom`, которое почти равно нулю к 14 дню

# %% [markdown]
# **5.5 Посмотрим ещё распределние по каналам для США**

# %%
#выделим отдельно пользователей из сша
usa_profiles = profiles.query('region == "United States"')

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(usa_profiles, orders, observation_date, horizon_days, ['channel'])
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days)

# %% [markdown]
# **ОБЩИЙ ВЫВОД:**
#
# 1. В целом реклама не окупается. К 14 дню Return On Investment равен примерно `98%`
#
#
# 2. Исходя из графиков ROI с разбивками, мы можем предположить, что на окупаемость рекламы влияют **страны:** `США`, **устройства:** `Iphone и MAC`, **каналы:** `AdNonSense`, `TipTop` и `FaceBoom`
#
#
# 3. По-моему мнению, одна из причин провала окупаемости рекламы - это слишком большие траты на рекламу в Соединенных Штатах Америки. Так как это единственная страна, которая не пересекает уровень окупаемости рекламы, но вложений на рекламу в этой стране значительно больше всех
#
#
# 4. На графике мы четко видим проблему окупаемости рекламы в Америке. Самые большие траты на каналы `TipTop` и `FaceBoom`, но в то же время только эти два канала привлечения не окупается

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Комментарий ревьюера</b>
#
# <s> <b>Ошибка:</b><br>
# Но так как мы обнаружили у США ROI меньше 1, можно еще посмотреть - какими каналами пользуется Америка. Можно построить для Америки с разбивкой по каналам графики: LTV, ROI, удержание, конверсию. И выделить перспективный канал.<br>
#
# Или посмотреть какими каналами пользуется США и на основании уже построенных графиков ROI, конверсии, удержания предложить перераспределить бюджет в пользу других каналов.<br>
# Денис, дай, пожалуйста, рекомендации - какими каналами пользоваться в США)   </s>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Комментарий студента</b>
#
# <b>Изменения:</b> добавил распределение по каналам в штатах и ниже дал свои рекомендации<br></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Комментарий ревьюера V-2</b>
#
# <b>Успех:</b><br>
#     👍 Действительно, надо не отказываться от рынка в США, а перераспределить бюджет.<br>
# Я только добавлю к твоему выводу.    <br>
# Если посмотреть на графики для Америки, можно выделить еще RocketSuperAds, у него ROI и удержание хорошие, конверсия неплохая)  <br>
# Вот его, к примеру, также можно рекомендовать для США.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Комментарий ревьюера V-2</b>
#
# <b>Совет:</b><br>
#
# Здесь еще можно было провести дополнительное исследование. Мы увидели динамику расходов по каналам во времени. И интересно посмотреть динамику привлечения пользователей по каналам во времени, т.е. сколько пользователей у каждого канала ежемесячно. Таким образом сравним - растет ли так кол-во пользователей как траты - ежемесячно.
# </div>

# %% [markdown]
# # Шаг 6. Напишите выводы
# - Выделите причины неэффективности привлечения пользователей;
# - Сформируйте рекомендации для отдела маркетинга для повышения эффективности.

# %% [markdown]
# 1. Из исследовательского анализа метривыше, мы можем видеть, что одна из главных причин неэффективности привлечеия пользователей - это вложение средств в неправильные каналы привлчения. Например, как мы видим, реклама не окупается в США и на таких устройствах, как MAC и IPHONE. Также следует заметить, что именно в Штатах самое большое количество пользователей Iphone и MAC.
#
#
# 2. Я бы порекомендовал не отказываться от рынка в США, так как самое большое количество пользователей именно оттуда. Но я бы советовал немного сократить вложения на рекламу в этой стране, а тратить больше средств на такие рекламные каналы, как `YRabbit` или `lambdaMediaAds`. И также я считаю, что в Германии, Великобритании и Франции нужно вкладывать в привлечение пользователей PC, так как ROI с разбивкой по девайсам самое лучшее у PC и этот девайс самый популярный в данных трёх странах.
#
#
# 3. Касаемо США, я бы советовал маркетологам сократить бюджет на привление пользователей из каналов `TipTop` и `FaceBoom` и вкладывать эти средства в два самых перспективных канала в Америке - `YRabbit и MediaTornado`

# %% [markdown]
# <div style="background: #cceeaa; padding: 5px; border: 1px solid green; border-radius: 5px;">
# <font color='green'>
#     <b><u>Общий вывод по проекту</u></b>
# <font color='green'><br>
#
#
# Денис, проделана огромная работа, ты - молодец! Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
# **Что мне особенно понравилось в твоей работе:**:
#
#
# * Код логичный и понятный, нет ничего лишнего.
# * Проект полностью соответствует плану!
# * Заданы все необходимые функции)
# * Маркетинг, исследовательский анализ и оценка окупаемости выполнены хорошо!
#
#
#
# **На что стоит обратить внимание**:
#
# * Осталось совсем немного поправить, а именно: рассчитать % платящих пользователей для каждого региона/устройста/канала, построить график расходов по каналам по неделям, поправить profiles, рекомендовать каналы для Америки. Подсказки ты найдешь в моих комментариях.
#
#
#
#
# **Доработка займет у тебя совсем немного времени) Желаю удачи и жду твой проект на повторное ревью!**😉
